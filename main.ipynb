# %%
# !uv pip install -e .

# %%
from cheesesnake import Cheesesnake

# %%
cs = Cheesesnake()

# %%
len(cs.datasets)

# %%
cs.query("SELECT * FROM datasets").df().head()

# %%
await cs.load_all_into_tables(show_progress=True)

# %%
(
    cs.query("SELECT title, resources FROM datasets")
    .filter(
        """
  (SELECT COUNT(*) 
   FROM UNNEST(resources) AS r(format, name, url) 
   WHERE format = 'geoparquet') > 0
"""
    )
    .show()
)

# %%
cs.query("SELECT title FROM datasets WHERE LOWER(title) LIKE '%septa%'")

# %%
cs.tables()
